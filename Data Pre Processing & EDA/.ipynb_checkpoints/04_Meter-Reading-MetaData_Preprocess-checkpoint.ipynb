# %%
# Importing the required libraries 
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import glob
from pyculiarity import detect_ts

# %% [markdown]
# # Load Meter and Meta Data

# %%
all_meters = pd.read_csv("../data/meters/cleaned/allmeters_daily.csv")
meta_data = pd.read_csv("../data/metadata/metadata.csv")

# %% [markdown]
# We are only interested looking at Energy Consumption by Educational Institutions and hence using the primaryspaceusage to filter for Educational Institions

# %%
meta_education = meta_data[meta_data['primaryspaceusage'] == 'Education']
meta_education
# Out:
#                       building_id   site_id  building_id_kaggle  \
# 3       Panther_education_Rosalie   Panther                 0.0
# 4         Panther_education_Misty   Panther                 1.0
# 6        Panther_education_Mattie   Panther                 2.0
# 8         Panther_education_Diann   Panther                 3.0
# 9          Panther_education_Gina   Panther                 4.0
# ...                           ...       ...                 ...
# 1618     Cockatoo_education_Marva  Cockatoo              1438.0
# 1619    Cockatoo_education_Collin  Cockatoo              1439.0
# 1621    Cockatoo_education_Gussie  Cockatoo              1441.0
# 1623     Cockatoo_education_Arlen  Cockatoo              1443.0
# 1625  Cockatoo_education_Victoria  Cockatoo              1445.0
#
#       site_id_kaggle primaryspaceusage sub_primaryspaceusage      sqm  \
# 3                0.0         Education              Research    690.5
# 4                0.0         Education              Research    252.7
# 6                0.0         Education             Classroom    499.4
# 8                0.0         Education             Classroom   2200.4
# 9                0.0         Education              Research  10833.1
# ...              ...               ...                   ...      ...
# 1618            15.0         Education     College Classroom  10123.7
# 1619            15.0         Education    College Laboratory   5248.7
# 1621            15.0         Education    College Laboratory   2800.4
# 1623            15.0         Education     College Classroom   3745.0
# 1625            15.0         Education     College Classroom    399.3
#
#           sqft        lat        lng  ... yearbuilt date_opened  \
# 3       7432.0  28.517689 -81.379039  ...    2008.0         NaN
# 4       2720.0  28.517689 -81.379039  ...    2004.0         NaN
# 6       5376.0  28.517689 -81.379039  ...    1991.0         NaN
# 8      23685.0  28.517689 -81.379039  ...    2002.0         NaN
# 9     116607.0  28.517689 -81.379039  ...    1975.0         NaN
# ...        ...        ...        ...  ...       ...         ...
# 1618  108971.0  42.459837 -76.485292  ...    1990.0         NaN
# 1619   56497.0  42.459837 -76.485292  ...    1957.0         NaN
# 1621   30143.0  42.459837 -76.485292  ...    1951.0         NaN
# 1623   40311.0  42.459837 -76.485292  ...    1913.0         NaN
# 1625    4298.0  42.459837 -76.485292  ...       NaN         NaN
#
#      numberoffloors occupants energystarscore  eui site_eui source_eui  \
# 3               NaN       NaN             NaN  276      NaN        NaN
# 4               NaN       NaN             NaN  375      NaN        NaN
# 6               NaN       NaN             NaN   49      NaN        NaN
# 8               NaN       NaN             NaN  145      NaN        NaN
# 9               NaN       NaN             NaN  546      NaN        NaN
# ...             ...       ...             ...  ...      ...        ...
# 1618            NaN       NaN             NaN  NaN      NaN        NaN
# 1619            NaN       NaN             NaN  NaN      NaN        NaN
# 1621            NaN       NaN             NaN  NaN      NaN        NaN
# 1623            NaN       NaN             NaN  NaN      NaN        NaN
# 1625            NaN       NaN             NaN  NaN      NaN        NaN
#
#      leed_level rating
# 3           NaN    NaN
# 4           NaN    NaN
# 6           NaN    NaN
# 8           NaN    NaN
# 9           NaN    NaN
# ...         ...    ...
# 1618        NaN    NaN
# 1619        NaN    NaN
# 1621        NaN    NaN
# 1623        NaN    NaN
# 1625        NaN    NaN
#
# [617 rows x 32 columns]

# %% [markdown]
# We have 617 buildings that were used for Educational purposes

# %%
# Since not all buildings use all energy sources, marking the sources used for each building 
meter_columns = ['electricity', 'hotwater', 'chilledwater', 'steam', 'water', 'irrigation', 'solar', 'gas']
for col in meter_columns:
    meta_education[col] = np.where(meta_education[col] == 'Yes', 1, 0)
# Out:
# /var/folders/46/4q6_331j7qx5_bf3yg_mv9km0000gn/T/ipykernel_82983/597666801.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_education[col] = np.where(meta_education[col] == 'Yes', 1, 0)

# %%
# Melt the DataFrame to pivot it
meta_melted = meta_education.melt(id_vars=[col for col in meta_education.columns if col not in meter_columns], 
                    value_vars=meter_columns, 
                    var_name='meter', 
                    value_name='value')

# %%
# Merging both the dataframes together
merged_df = pd.merge(all_meters, meta_melted, on=['building_id','meter' ], how='inner') 
merged_df = merged_df[merged_df['value'] == 1]

# %%
merged_df.columns
# Out:
# Index(['building_id', 'meter', 'date', 'meter_reading', 'site_id',
#        'building_id_kaggle', 'site_id_kaggle', 'primaryspaceusage',
#        'sub_primaryspaceusage', 'sqm', 'sqft', 'lat', 'lng', 'timezone',
#        'industry', 'subindustry', 'heatingtype', 'yearbuilt', 'date_opened',
#        'numberoffloors', 'occupants', 'energystarscore', 'eui', 'site_eui',
#        'source_eui', 'leed_level', 'rating', 'value'],
#       dtype='object')

# %%
merged_df.head()
# Out:
#               building_id        meter        date  meter_reading site_id  \
# 0  Bear_education_Alfredo  electricity  2016-01-01         2.9050    Bear
# 1  Bear_education_Alfredo  electricity  2016-01-02         2.7700    Bear
# 2  Bear_education_Alfredo  electricity  2016-01-03         2.6725    Bear
# 3  Bear_education_Alfredo  electricity  2016-01-04         4.5650    Bear
# 4  Bear_education_Alfredo  electricity  2016-01-05         4.7825    Bear
#
#    building_id_kaggle  site_id_kaggle primaryspaceusage sub_primaryspaceusage  \
# 0               636.0             4.0         Education             Education
# 1               636.0             4.0         Education             Education
# 2               636.0             4.0         Education             Education
# 3               636.0             4.0         Education             Education
# 4               636.0             4.0         Education             Education
#
#      sqm  ...  date_opened  numberoffloors  occupants energystarscore  eui  \
# 0  609.8  ...          NaN             3.0        NaN             NaN  NaN
# 1  609.8  ...          NaN             3.0        NaN             NaN  NaN
# 2  609.8  ...          NaN             3.0        NaN             NaN  NaN
# 3  609.8  ...          NaN             3.0        NaN             NaN  NaN
# 4  609.8  ...          NaN             3.0        NaN             NaN  NaN
#
#   site_eui source_eui  leed_level rating  value
# 0      NaN        NaN         NaN    NaN      1
# 1      NaN        NaN         NaN    NaN      1
# 2      NaN        NaN         NaN    NaN      1
# 3      NaN        NaN         NaN    NaN      1
# 4      NaN        NaN         NaN    NaN      1
#
# [5 rows x 28 columns]

# %%
# Inspecting the dataframe for a single building id 
merged_df[merged_df['building_id_kaggle'] == 636]
# Out:
#                 building_id        meter        date  meter_reading site_id  \
# 0    Bear_education_Alfredo  electricity  2016-01-01         2.9050    Bear
# 1    Bear_education_Alfredo  electricity  2016-01-02         2.7700    Bear
# 2    Bear_education_Alfredo  electricity  2016-01-03         2.6725    Bear
# 3    Bear_education_Alfredo  electricity  2016-01-04         4.5650    Bear
# 4    Bear_education_Alfredo  electricity  2016-01-05         4.7825    Bear
# ..                      ...          ...         ...            ...     ...
# 726  Bear_education_Alfredo  electricity  2017-12-27         3.9825    Bear
# 727  Bear_education_Alfredo  electricity  2017-12-28         3.9975    Bear
# 728  Bear_education_Alfredo  electricity  2017-12-29         3.3650    Bear
# 729  Bear_education_Alfredo  electricity  2017-12-30         3.1825    Bear
# 730  Bear_education_Alfredo  electricity  2017-12-31         3.1800    Bear
#
#      building_id_kaggle  site_id_kaggle primaryspaceusage  \
# 0                 636.0             4.0         Education
# 1                 636.0             4.0         Education
# 2                 636.0             4.0         Education
# 3                 636.0             4.0         Education
# 4                 636.0             4.0         Education
# ..                  ...             ...               ...
# 726               636.0             4.0         Education
# 727               636.0             4.0         Education
# 728               636.0             4.0         Education
# 729               636.0             4.0         Education
# 730               636.0             4.0         Education
#
#     sub_primaryspaceusage    sqm  ...  date_opened  numberoffloors  occupants  \
# 0               Education  609.8  ...          NaN             3.0        NaN
# 1               Education  609.8  ...          NaN             3.0        NaN
# 2               Education  609.8  ...          NaN             3.0        NaN
# 3               Education  609.8  ...          NaN             3.0        NaN
# 4               Education  609.8  ...          NaN             3.0        NaN
# ..                    ...    ...  ...          ...             ...        ...
# 726             Education  609.8  ...          NaN             3.0        NaN
# 727             Education  609.8  ...          NaN             3.0        NaN
# 728             Education  609.8  ...          NaN             3.0        NaN
# 729             Education  609.8  ...          NaN             3.0        NaN
# 730             Education  609.8  ...          NaN             3.0        NaN
#
#     energystarscore  eui site_eui source_eui  leed_level rating  value
# 0               NaN  NaN      NaN        NaN         NaN    NaN      1
# 1               NaN  NaN      NaN        NaN         NaN    NaN      1
# 2               NaN  NaN      NaN        NaN         NaN    NaN      1
# 3               NaN  NaN      NaN        NaN         NaN    NaN      1
# 4               NaN  NaN      NaN        NaN         NaN    NaN      1
# ..              ...  ...      ...        ...         ...    ...    ...
# 726             NaN  NaN      NaN        NaN         NaN    NaN      1
# 727             NaN  NaN      NaN        NaN         NaN    NaN      1
# 728             NaN  NaN      NaN        NaN         NaN    NaN      1
# 729             NaN  NaN      NaN        NaN         NaN    NaN      1
# 730             NaN  NaN      NaN        NaN         NaN    NaN      1
#
# [731 rows x 28 columns]

# %% [markdown]
# # Missing Data

# %%
def determine_column_counts(df):
    columns = df.columns
    data_counts = pd.DataFrame(columns = ['column_name','column_type','num_rows','distinct_data', 'distinct_percent', 'missing_data', 'missing_percentage'])
    
    #For each column, calculate number and percentage of missing rows and distinct counts
    for col in columns:
        col_vals = df[col]
        total_data = len(col_vals)
        col_missing = sum(col_vals.isnull())
        missing_percent = round((col_missing / len(df[col])) * 100 , 3)
        col_distinct = (col_vals.nunique())
        distinct_percent = round((col_distinct / len(df[col])) * 100 , 3)

        data_counts.loc[len(data_counts)] = [col, col_vals.dtype, total_data, col_distinct, distinct_percent, col_missing, missing_percent]
        
    return(data_counts)

missing_data = determine_column_counts(merged_df)
missing_data
# Out:
#               column_name column_type  num_rows  distinct_data  \
# 0             building_id      object    894013            617
# 1                   meter      object    894013              8
# 2                    date      object    894013            731
# 3           meter_reading     float64    894013         589584
# 4                 site_id      object    894013             15
# 5      building_id_kaggle     float64    894013            549
# 6          site_id_kaggle     float64    894013             15
# 7       primaryspaceusage      object    894013              1
# 8   sub_primaryspaceusage      object    894013             13
# 9                     sqm     float64    894013            605
# 10                   sqft     float64    894013            605
# 11                    lat     float64    894013             13
# 12                    lng     float64    894013             13
# 13               timezone      object    894013              6
# 14               industry      object    894013              2
# 15            subindustry      object    894013              2
# 16            heatingtype      object    894013              7
# 17              yearbuilt     float64    894013            101
# 18            date_opened      object    894013              0
# 19         numberoffloors     float64    894013             17
# 20              occupants     float64    894013             81
# 21        energystarscore      object    894013              1
# 22                    eui      object    894013             60
# 23               site_eui      object    894013             26
# 24             source_eui      object    894013             26
# 25             leed_level      object    894013              1
# 26                 rating      object    894013              8
# 27                  value       int64    894013              1
#
#     distinct_percent  missing_data  missing_percentage
# 0              0.069             0               0.000
# 1              0.001             0               0.000
# 2              0.082             0               0.000
# 3             65.948             0               0.000
# 4              0.002             0               0.000
# 5              0.061         79679               8.913
# 6              0.002             0               0.000
# 7              0.000             0               0.000
# 8              0.001             0               0.000
# 9              0.068             0               0.000
# 10             0.068             0               0.000
# 11             0.001        103071              11.529
# 12             0.001        103071              11.529
# 13             0.001             0               0.000
# 14             0.000        466378              52.167
# 15             0.000        466378              52.167
# 16             0.001        755123              84.464
# 17             0.011        407167              45.544
# 18             0.000        894013             100.000
# 19             0.002        619888              69.338
# 20             0.009        722228              80.785
# 21             0.000        847960              94.849
# 22             0.007        786556              87.980
# 23             0.003        847960              94.849
# 24             0.003        847960              94.849
# 25             0.000        883779              98.855
# 26             0.001        760971              85.119
# 27             0.000             0               0.000

# %% [markdown]
# On the basis of missing values and domain knowledge we shall drop the following columns since they are not directly consequential to our analysis

# %%
cleaned_df = merged_df.drop(columns = ['primaryspaceusage', 'lat', 'lng','industry', 'subindustry',
                                      'heatingtype', 'yearbuilt', 'date_opened', 'numberoffloors', 'occupants', 'energystarscore', 
                                      'eui', 'site_eui', 'source_eui','leed_level', 'rating', 'value' ])

# %%
cleaned_df.to_csv("../data/cleaned/cleaned_meters_meta.csv")

# %%
cleaned_df
# Out:
#                    building_id        meter        date  meter_reading  \
# 0       Bear_education_Alfredo  electricity  2016-01-01         2.9050
# 1       Bear_education_Alfredo  electricity  2016-01-02         2.7700
# 2       Bear_education_Alfredo  electricity  2016-01-03         2.6725
# 3       Bear_education_Alfredo  electricity  2016-01-04         4.5650
# 4       Bear_education_Alfredo  electricity  2016-01-05         4.7825
# ...                        ...          ...         ...            ...
# 894008   Wolf_education_Vivian        water  2017-12-27      2957.4056
# 894009   Wolf_education_Vivian        water  2017-12-28      1713.1557
# 894010   Wolf_education_Vivian        water  2017-12-29      2110.7344
# 894011   Wolf_education_Vivian        water  2017-12-30      1809.5784
# 894012   Wolf_education_Vivian        water  2017-12-31      1281.2342
#
#        site_id  building_id_kaggle  site_id_kaggle sub_primaryspaceusage  \
# 0         Bear               636.0             4.0             Education
# 1         Bear               636.0             4.0             Education
# 2         Bear               636.0             4.0             Education
# 3         Bear               636.0             4.0             Education
# 4         Bear               636.0             4.0             Education
# ...        ...                 ...             ...                   ...
# 894008    Wolf              1049.0            12.0     College Classroom
# 894009    Wolf              1049.0            12.0     College Classroom
# 894010    Wolf              1049.0            12.0     College Classroom
# 894011    Wolf              1049.0            12.0     College Classroom
# 894012    Wolf              1049.0            12.0     College Classroom
#
#            sqm     sqft       timezone
# 0        609.8   6564.0     US/Pacific
# 1        609.8   6564.0     US/Pacific
# 2        609.8   6564.0     US/Pacific
# 3        609.8   6564.0     US/Pacific
# 4        609.8   6564.0     US/Pacific
# ...        ...      ...            ...
# 894008  8770.0  94399.0  Europe/Dublin
# 894009  8770.0  94399.0  Europe/Dublin
# 894010  8770.0  94399.0  Europe/Dublin
# 894011  8770.0  94399.0  Europe/Dublin
# 894012  8770.0  94399.0  Europe/Dublin
#
# [894013 rows x 11 columns]
